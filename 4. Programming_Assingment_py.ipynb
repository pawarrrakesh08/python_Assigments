# %% [markdown]
# ### 1. Write a Python Program to Find the Factorial of a Number?

# %%
num = int(input("Enter the number: "))
f = 1
while (num>0):
    f = f*num
    num = num - 1
print("Factorial =", f)
# Out:
# Enter the number: 12
# Factorial = 479001600

# %% [markdown]
# ### 2. Write a Python Program to Display the multiplication Table?

# %%
num = int(input("Enter the number: "))

t = 10
for i in range(1,t+1):
    print(num*i)
# Out:
# Enter the number: 12
# 12
# 24
# 36
# 48
# 60
# 72
# 84
# 96
# 108
# 120

# %% [markdown]
# ### 3. Write a Python Program to Print the Fibonacci sequence?
# ![image.png](attachment:image.png)

# %%
num = int(input("Enter a number: "))

a = 0
b = 1
c = 0

while (c<= num):
    print(c)
    a = b
    b = c
    c = a+b
# Out:
# Enter a number: 12
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %% [markdown]
# ### 4. Write a Python Program to Check Armstrong Number?
# ![image.png](attachment:image.png)

# %%
num = int(input("Enter a Positive Number: "))
x = len(str(num))
sum = 0

original = num

while original > 0:
    digit = original % 10
    sum += digit**x
    original //= 10
if num == sum:
   print(num,"is an Armstrong number")
else:
   print(num,"is not an Armstrong number")
# Out:
# Enter a Positive Number: 153
# 153 is an Armstrong number

# %% [markdown]
# ### 5. Write a Python Program to Find Armstrong Number in an Interval?

# %%
startnumber = int(input("Enter the postive Start Number: "))
endnumber = int(input("Enter the postive End Number: "))

for num in range(startnumber, endnumber + 1):

   # order of number
   order = len(str(num))
    
   # initialize sum
   sum = 0

   temp = num
   while temp > 0:
       digit = temp % 10
       sum += digit ** order
       temp //= 10

   if num == sum:
       print(num)
# Out:
# Enter the postive Start Number: 153
# Enter the postive End Number: 15546
# 153
# 370
# 371
# 407
# 1634
# 8208
# 9474

# %% [markdown]
# ### 6. Write a Python Program to Find the Sum of Natural Numbers?
# ![image.png](attachment:image.png)

# %%
num = int(input("Enter a Positive Number: "))
sum = 0
while(num > 0):
    sum += num
    num -= 1
print("The sum is", sum)
# Out:
# Enter a Positive Number: 153
# The sum is 11781
